# %%
import pandas as pd

# %%
data = pd.read_csv("data_filtered.csv")

# %%
final_data = data[["business_id", "stars_x", "review_id", "user_id", "text", "has_exclamation", "has_question", "is_shouting", "food_sentiment", "service_sentiment", "atmosphere_sentiment", "overall_sentiment", "grade_level"]]

# %%
final_data.to_csv("modelling_data.csv")
