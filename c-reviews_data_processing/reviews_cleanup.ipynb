# %%
import pandas as pd

reviews = pd.read_csv("readability_reviews.csv")

# %%
reviews.columns
# Out:
# Index(['Unnamed: 0', 'review_id', 'user_id', 'business_id', 'stars_x', 'text',
#        'date', 'name', 'city', 'state', 'review_count', 'attributes',
#        'categories', 'hours', 'is_restaurant', 'has_exclamation',
#        'has_question', 'uppercase_ratio', 'is_shouting', 'length',
#        'food_sentiment', 'service_sentiment', 'atmosphere_sentiment',
#        'overall_sentiment', 'grade_level'],
#       dtype='object')

# %%
reviews = reviews.drop(["city", "attributes", "review_count", "categories", "hours", "Unnamed: 0", "name"], axis=1)

# %%
reviews.columns
# Out:
# Index(['review_id', 'user_id', 'business_id', 'stars_x', 'text', 'date',
#        'state', 'is_restaurant', 'has_exclamation', 'has_question',
#        'uppercase_ratio', 'is_shouting', 'length', 'food_sentiment',
#        'service_sentiment', 'atmosphere_sentiment', 'overall_sentiment',
#        'grade_level'],
#       dtype='object')

# %%
reviews.to_csv("final_processed_reviews.csv")
