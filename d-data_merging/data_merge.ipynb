# %%
import pandas as pd

df1 = pd.read_csv('business_features_processed.csv')
df2 = pd.read_csv('final_processed_reviews.csv')

merged_df = pd.merge(df1, df2, on='business_id', how='inner')

merged_df.to_csv('data.csv', index=False)

# %%
print(merged_df)
# Out:
#                   business_id                    name state_x  stars  \
# 0      zxJfzu6Hy4E5bjP9fzh93g                 Nikki's      AB    4.0
# 1      zxJfzu6Hy4E5bjP9fzh93g                 Nikki's      AB    4.0
# 2      zxJfzu6Hy4E5bjP9fzh93g                 Nikki's      AB    4.0
# 3      zxJfzu6Hy4E5bjP9fzh93g                 Nikki's      AB    4.0
# 4      zxJfzu6Hy4E5bjP9fzh93g                 Nikki's      AB    4.0
# ...                       ...                     ...     ...    ...
# 46452  et96-0iMUgkDiQWKqr4k2g  The Bean Bistro & Cafe      TN    3.5
# 46453  et96-0iMUgkDiQWKqr4k2g  The Bean Bistro & Cafe      TN    3.5
# 46454  et96-0iMUgkDiQWKqr4k2g  The Bean Bistro & Cafe      TN    3.5
# 46455  et96-0iMUgkDiQWKqr4k2g  The Bean Bistro & Cafe      TN    3.5
# 46456  et96-0iMUgkDiQWKqr4k2g  The Bean Bistro & Cafe      TN    3.5
#
#        review_count  OutdoorSeating  RestaurantsDelivery  \
# 0                 8               0                    0
# ...
